# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##### Load in Datasets, Perform Basic Cleaning

# %%
train_df = pd.read_csv("data/train.csv").dropna()
test_df = pd.read_csv("data/test.csv").dropna()

# %%
train_df.head(1)
# Out:
#    ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 0   1     2     23                 0.0                      0.0
#
#    imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# 0                      0.0                      0.0                      0.0
#
#    imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  ...  \
# 0                      0.0                      0.0  ...
#
#    saldo_medio_var33_hace2  saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# 0                      0.0                      0.0                     0.0
#
#    saldo_medio_var33_ult3  saldo_medio_var44_hace2  saldo_medio_var44_hace3  \
# 0                     0.0                      0.0                      0.0
#
#    saldo_medio_var44_ult1  saldo_medio_var44_ult3     var38  TARGET
# 0                     0.0                     0.0  39205.17       0
#
# [1 rows x 371 columns]

# %%
X = train_df.drop('TARGET',axis=1)
y = train_df[['TARGET']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=42)

# %%
# Optional Scaling

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ##### Select Features (Columns) and Target Values of Interest

# %% [markdown]
# ##### Data Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ##### Create the Model

# %%
c_version2 = DecisionTreeClassifier(min_samples_split=5702)

c_version2.fit(X_train,y_train)

plt.figure(figsize=(40,40))
tree.plot_tree(c_version2)
plt.show()

# %%
y_prediction = c_version2.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, y_prediction) * 100

# %%
print(f"The Y-Prediction Value has an Accuracy of {round(score,1)}% against the Y-Test Dataset.")
# Out:
# The Y-Prediction Value has an Accuracy of 96.0% against the Y-Test Dataset.
